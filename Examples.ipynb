# %% [markdown]
# <a href="https://colab.research.google.com/github/MedeEswar/MedeEswar/blob/main/Examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

mylist = [50, 100, 150, 200, 250]

res = pd.Series(mylist)

print("Series is=\n", res)
# Out:
# Series is=
#  0     50
# 1    100
# 2    150
# 3    200
# 4    250
# dtype: int64

# %%
import numpy as np

arr = np.array((1, 2, 3, 4))

print("Array =",arr)

print(type(arr))
# Out:
# Array = [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpts = ([0, 5])
ypts = ([0, 136])

plt.plot(xpts, ypts)
plt.show()
